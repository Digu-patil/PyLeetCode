# %%
import sys
import inspect
from pprint import pprint

# %%
# Ref count increases by one when new namespace refer the object.
k = 16789
print(sys.getrefcount(k))
q = k
print(sys.getrefcount(k))
# Out:
# 3
# 4

# %%
# Getting the recursion limit
print(sys.getrecursionlimit())

# Modifying the recusion limit
sys.setrecursionlimit(2000)
print(sys.getrecursionlimit())
# Out:
# 3000
# 2000

# %%
# Inspceting where the variables or namespaces live

a = 20
b = [20,60,80]

def outer(a):
    x = 10
    outer_frame = inspect.currentframe()
    print(f'Stack frame created for the following function -> {outer_frame.f_code.co_name}')
    print(f'These are local var to outer function -> {outer_frame.f_locals}')
    print(f'These are global var to outer function {outer_frame.f_globals}')

    # We can also access the global variable using the modules object, where they originally live
    print(sys.modules['__main__'].__dict__)
    def inner():
        p = a + x
        inner_frame = inspect.currentframe()
        print(f'Stack frame created for the following function -> {inner_frame.f_code.co_name}')
        print(f'These are local var to inner function -> {inner_frame.f_locals}')
        print(f'These are global var to inner function -> {inner_frame.f_globals}')
        return p
    return inner

b = outer(a)
b()
# Out:
# Stack frame created for the following function -> outer
# These are local var to outer function -> {'a': 20, 'outer_frame': <frame at 0x00000127B133C380, file 'C:\\Users\\imdig\\AppData\\Local\\Temp\\ipykernel_30716\\1679825602.py', line 10, code outer>, 'x': 10}
# These are global var to outer function {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import sys\nimport inspect', '# \na = 1000\nprint(sys.getrefcount(a))', '# \nk = 16789\nprint(sys.getrefcount(k))', 'q = k\nprint(sys.getrefcount(q))', 'q = k\nprint(sys.getrefcount(qk))', 'q = k\nprint(sys.getrefcount(k))', '# \nk = 16789\nprint(sys.getrefcount(k))\nq = k\nprint(sys.getrefcount(k))', '# Getting the recursion limit\nprint(sys.getrecursionlimit())', '# Getting the recursion limit\nprint(sys.getrecursionlimit())\n\n# Modifying the recusion limit\nsys.setrecursionlimit(2000)\nprint(sys.getrecursionlimit())', "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are local var to outer function {outer_frame.f_globals}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are local var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_locals.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function -> {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n   ...
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import sys\nimport inspect', '# \na = 1000\nprint(sys.getrefcount(a))', '# \nk = 16789\nprint(sys.getrefcount(k))', 'q = k\nprint(sys.getrefcount(q))', 'q = k\nprint(sys.getrefcount(qk))', 'q = k\nprint(sys.getrefcount(k))', '# \nk = 16789\nprint(sys.getrefcount(k))\nq = k\nprint(sys.getrefcount(k))', '# Getting the recursion limit\nprint(sys.getrecursionlimit())', '# Getting the recursion limit\nprint(sys.getrecursionlimit())\n\n# Modifying the recusion limit\nsys.setrecursionlimit(2000)\nprint(sys.getrecursionlimit())', "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are local var to outer function {outer_frame.f_globals}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are local var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_locals.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function -> {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to ou ...
# {'p': 30, 'inner_frame': <frame at 0x00000127B133C1E0, file 'C:\\Users\\imdig\\AppData\\Local\\Temp\\ipykernel_30716\\1679825602.py', line 18, code inner>, 'a': 20, 'x': 10}
# Stack frame created for the following function -> inner
# These are local var to inner function -> {'p': 30, 'inner_frame': <frame at 0x00000127B133C1E0, file 'C:\\Users\\imdig\\AppData\\Local\\Temp\\ipykernel_30716\\1679825602.py', line 20, code inner>, 'a': 20, 'x': 10}
# These are global var to inner function -> {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import sys\nimport inspect', '# \na = 1000\nprint(sys.getrefcount(a))', '# \nk = 16789\nprint(sys.getrefcount(k))', 'q = k\nprint(sys.getrefcount(q))', 'q = k\nprint(sys.getrefcount(qk))', 'q = k\nprint(sys.getrefcount(k))', '# \nk = 16789\nprint(sys.getrefcount(k))\nq = k\nprint(sys.getrefcount(k))', '# Getting the recursion limit\nprint(sys.getrecursionlimit())', '# Getting the recursion limit\nprint(sys.getrecursionlimit())\n\n# Modifying the recusion limit\nsys.setrecursionlimit(2000)\nprint(sys.getrecursionlimit())', "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are local var to outer function {outer_frame.f_globals}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are local var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_locals.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\n        print(f'These are local var to outer function {inner_frame.f_locals}')\n        print(f'These are global var to outer function {inner_frame.f_globals}')\n        return p\n    return inner\n\nb = outer(a)", "# Inspceting where the variables or namespaces live\n\na = 20\nb = [20,60,80]\n\ndef outer(a):\n    x = 10\n    outer_frame = inspect.currentframe()\n    print(f'These are local var to outer function {outer_frame.f_locals}')\n    print(f'These are global var to outer function {outer_frame.f_globals}')\n    print(f'Stack frame created for the following function -> {outer_frame.f_code.co_name}')\n    def inner():\n        p = a + x\n        inner_frame = inspect.currentframe()\ ...
# 30
